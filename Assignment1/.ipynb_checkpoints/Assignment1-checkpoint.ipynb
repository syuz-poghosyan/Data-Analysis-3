# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv("C:/Users/Poghosyan_Syuzanna/Desktop/SyuzannaPoghosyan/morg-2014-emp.csv", low_memory=False)
df
# Out:
#         Unnamed: 0             hhid  intmonth stfips     weight  earnwke  \
# 0                3    2600310997690   January     AL  3151.6801  1692.00
# 1                5   75680310997590   January     AL  3457.1138   450.00
# 2                6   75680310997590   January     AL  3936.9110  1090.00
# 3               10  179140131100930   January     AL  3288.3640   769.23
# 4               11  179140131100930   January     AL  3422.8500   826.92
# ...            ...              ...       ...    ...        ...      ...
# 149311      317051  896679860459501  December     WY   346.2296   692.30
# 149312      317052  907086820569600  December     WY   294.9800  1984.61
# 149313      317053  907086820569600  December     WY   324.1761  2884.61
# 149314      317055  950868097156649  December     WY   321.6982  1153.84
# 149315      317056  950868097156649  December     WY   294.9800   673.07
#
#         uhours  grade92  race  ethnic  ...  ownchild  chldpres  \
# 0           40       43     1     NaN  ...         0         0
# 1           40       41     2     NaN  ...         2         6
# 2           60       41     2     NaN  ...         2         6
# 3           40       40     1     NaN  ...         2         4
# 4           40       43     1     NaN  ...         2         4
# ...        ...      ...   ...     ...  ...       ...       ...
# 149311      40       39     1     NaN  ...         0         0
# 149312      40       44     1     NaN  ...         1         3
# 149313      55       43     1     NaN  ...         1         3
# 149314      40       42     1     NaN  ...         0         0
# 149315      40       40     1     NaN  ...         0         0
#
#                   prcitshp  state  \
# 0       Native, Born In US     63
# 1       Native, Born In US     63
# 2       Native, Born In US     63
# 3       Native, Born In US     63
# 4       Native, Born In US     63
# ...                    ...    ...
# 149311  Native, Born In US      8
# 149312  Native, Born In US      8
# 149313  Native, Born In US      8
# 149314  Native, Born In US      8
# 149315  Native, Born In US      8
#
#                                                     ind02 occ2012  \
# 0                              Employment services (5613)     630
# 1                          Outpatient care centers (6214)    5400
# 2       Motor vehicles and motor vehicle equipment man...    8140
# 3       **Publishing, except newspapers and software (...    8255
# 4       Banking and related activities (521, 52211,52219)    5940
# ...                                                   ...     ...
# 149311      Office supplies and stationery stores (45321)    4760
# 149312    Administration of human resource programs (923)     430
# 149313                     Nursing care facilities (6231)      10
# 149314                                    Hospitals (622)    5820
# 149315                 Pharmacies and drug stores (44611)    3420
#
#                       class unionmme  unioncov            lfsr94
# 0       Private, For Profit       No        No  Employed-At Work
# 1       Private, For Profit       No        No   Employed-Absent
# 2       Private, For Profit       No        No  Employed-At Work
# 3       Private, For Profit      Yes       NaN  Employed-At Work
# 4       Private, For Profit       No        No  Employed-At Work
# ...                     ...      ...       ...               ...
# 149311  Private, For Profit       No        No  Employed-At Work
# 149312   Government - State       No        No  Employed-At Work
# 149313  Private, For Profit       No        No  Employed-At Work
# 149314   Private, Nonprofit       No        No  Employed-At Work
# 149315  Private, For Profit       No        No  Employed-At Work
#
# [149316 rows x 23 columns]

# %% [markdown]
# # Filtering for Financial Specialists as I have been one for years (Occupation Code: from 0800 to 0950)

# %%
df = df[(df['occ2012'] >= 800) & (df['occ2012'] <= 950)].copy()
df
# Out:
#         Unnamed: 0             hhid  intmonth stfips     weight  earnwke  \
# 22              44  954001919079770   January     AL  3677.7816   680.00
# 53             125  507001320102921   January     AL  3296.7986  2000.00
# 56             131  510915094903939   January     AL  3419.5125  1923.00
# 80             187  210033043908195   January     AL  4563.6243   280.00
# 102            230  981071966079500   January     AL  2416.8545   800.00
# ...            ...              ...       ...    ...        ...      ...
# 149050      316537   50510000344676  December     WI  3677.2160   580.00
# 149091      316610  506902605991185  December     WI   403.3448  1538.46
# 149117      316653  955161170004307  December     WI  3794.4402  1057.69
# 149263      316934  816460901300501  December     WY   275.7171  1923.07
# 149296      317015  506605705991936  December     WY   277.3311   560.00
#
#         uhours  grade92  race  ethnic  ...  ownchild  chldpres  \
# 22          40       43     1     NaN  ...         0         0
# 53          50       44     1     NaN  ...         1         1
# 56          40       43     1     NaN  ...         2        10
# 80          32       42     1     NaN  ...         0         0
# 102         40       42     2     NaN  ...         1         4
# ...        ...      ...   ...     ...  ...       ...       ...
# 149050      42       43     1     NaN  ...         0         0
# 149091      48       43     1     NaN  ...         0         0
# 149117      40       42     1     NaN  ...         0         0
# 149263      40       43     1     NaN  ...         1         3
# 149296      40       43     1     NaN  ...         0         0
#
#                   prcitshp  state  \
# 22      Native, Born In US     63
# 53      Native, Born In US     63
# 56      Native, Born In US     63
# 80      Native, Born In US     63
# 102     Native, Born In US     63
# ...                    ...    ...
# 149050  Native, Born In US      3
# 149091  Native, Born In US      3
# 149117  Native, Born In US      3
# 149263  Native, Born In US      8
# 149296  Native, Born In US      8
#
#                                                     ind02 occ2012  \
# 22      Non-depository credit and related activities (...     800
# 53                                      Real estate (531)     800
# 56      Banking and related activities (521, 52211,52219)     910
# 80      Recreational vehicle parks and camps, and room...     800
# 102     Savings institutions, including credit unions ...     910
# ...                                                   ...     ...
# 149050                               ** Construction (23)     800
# 149091                     Nursing care facilities (6231)     840
# 149117                                  Real estate (531)     800
# 149263  Banking and related activities (521, 52211,52219)     910
# 149296                       Offices of physicians (6211)     800
#
#                       class unionmme  unioncov            lfsr94
# 22      Private, For Profit       No        No  Employed-At Work
# 53      Private, For Profit       No        No  Employed-At Work
# 56      Private, For Profit       No        No  Employed-At Work
# 80      Private, For Profit       No        No  Employed-At Work
# 102     Private, For Profit       No        No  Employed-At Work
# ...                     ...      ...       ...               ...
# 149050  Private, For Profit       No        No  Employed-At Work
# 149091   Private, Nonprofit       No        No  Employed-At Work
# 149117  Private, For Profit       No        No  Employed-At Work
# 149263  Private, For Profit       No        No  Employed-At Work
# 149296  Private, For Profit       No        No  Employed-At Work
#
# [3404 rows x 23 columns]

# %% [markdown]
# # Computing earnings per hour

# %%
df['earnings_per_hour'] = df['earnwke'] / df['uhours']

# %% [markdown]
# # Data Cleaning

# %%
print(df.columns)
df = df[['earnwke', 'uhours', 'marital', 'earnings_per_hour', 'grade92', 'age', 'sex', 'race', 'class']].dropna()

df
# Out:
# Index(['earnwke', 'uhours', 'marital', 'earnings_per_hour', 'grade92', 'age',
#        'sex', 'race', 'class', 'unionmme'],
#       dtype='object')
#         earnwke  uhours  marital  earnings_per_hour  grade92  age  sex  race  \
# 22       680.00      40        7          17.000000       43   27    1     1
# 53      2000.00      50        1          40.000000       44   48    1     1
# 56      1923.00      40        5          48.075000       43   47    1     1
# 80       280.00      32        7           8.750000       42   24    1     1
# 102      800.00      40        1          20.000000       42   42    2     2
# ...         ...     ...      ...                ...      ...  ...  ...   ...
# 149050   580.00      42        1          13.809524       43   51    2     1
# 149091  1538.46      48        1          32.051250       43   55    2     1
# 149117  1057.69      40        1          26.442250       42   55    1     1
# 149263  1923.07      40        1          48.076750       43   59    1     1
# 149296   560.00      40        1          14.000000       43   60    2     1
#
#                       class
# 22      Private, For Profit
# 53      Private, For Profit
# 56      Private, For Profit
# 80      Private, For Profit
# 102     Private, For Profit
# ...                     ...
# 149050  Private, For Profit
# 149091   Private, Nonprofit
# 149117  Private, For Profit
# 149263  Private, For Profit
# 149296  Private, For Profit
#
# [3290 rows x 9 columns]

# %%
# Defining the dependent variable (earnings per hour)
y = df['earnings_per_hour']

# %%
# Defining potential predicting variables (x)
predictors = ['grade92', 'age', 'sex', 'race', 'marital', 'class']

# %%
columns = ['earnings_per_hour']

plt.figure(figsize=(14, 10))

for i, column in enumerate(columns, 1):
    plt.subplot(3, 5, i) 
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %%
columns_with_outliers = ['earnings_per_hour']

def remove_outliers(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

df = remove_outliers(df, columns_with_outliers)

df
# Out:
#         earnwke  uhours  marital  earnings_per_hour  grade92  age  sex  race  \
# 22       680.00      40        7          17.000000       43   27    1     1
# 53      2000.00      50        1          40.000000       44   48    1     1
# 56      1923.00      40        5          48.075000       43   47    1     1
# 80       280.00      32        7           8.750000       42   24    1     1
# 102      800.00      40        1          20.000000       42   42    2     2
# ...         ...     ...      ...                ...      ...  ...  ...   ...
# 149050   580.00      42        1          13.809524       43   51    2     1
# 149091  1538.46      48        1          32.051250       43   55    2     1
# 149117  1057.69      40        1          26.442250       42   55    1     1
# 149263  1923.07      40        1          48.076750       43   59    1     1
# 149296   560.00      40        1          14.000000       43   60    2     1
#
#                       class
# 22      Private, For Profit
# 53      Private, For Profit
# 56      Private, For Profit
# 80      Private, For Profit
# 102     Private, For Profit
# ...                     ...
# 149050  Private, For Profit
# 149091   Private, Nonprofit
# 149117  Private, For Profit
# 149263  Private, For Profit
# 149296  Private, For Profit
#
# [3229 rows x 9 columns]

# %% [markdown]
# # Analyzing the dataset

# %%
plt.figure(figsize=(10, 6))
sns.histplot(y, kde=True, color='red')
plt.title('Distribution of Earnings per Hour')
plt.xlabel('Earnings per Hour')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation between the dependent variable and the potential predictors
correlation_matrix = df[['grade92', 'age', 'sex', 'race', 'marital', 'class', 'earnings_per_hour']].corr()
                
# Visualizing with a correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
round(df[['grade92', 'age', 'sex', 'race', 'class', 'marital', 'earnings_per_hour']].describe(), 3)
# Out:
#         grade92       age       sex      race   marital  earnings_per_hour
# count  3229.000  3229.000  3229.000  3229.000  3229.000           3229.000
# mean     42.386    41.816     1.615     1.404     3.025             27.955
# std       1.606    11.554     0.487     1.137     2.641             12.464
# min      31.000    17.000     1.000     1.000     1.000              0.010
# 25%      42.000    32.000     1.000     1.000     1.000             18.510
# 50%      43.000    42.000     2.000     1.000     1.000             25.000
# 75%      43.000    51.000     2.000     1.000     6.000             35.760
# max      46.000    64.000     2.000    21.000     7.000             62.000

# %% [markdown]
# # Defining all the models

# %%
# Model features for each of 4 models
model_features = [
    ['age'],
    ['age', 'sex', 'race'],
    ['age', 'sex', 'race', 'grade92'],
    ['age', 'sex', 'race', 'grade92', 'marital', 'class']  # Most complex model with all predictors
]

# %%
from sklearn.model_selection import KFold, cross_val_score

def preprocess_df(df, features):
    X = pd.get_dummies(df[features], drop_first=True)
    X = X.apply(pd.to_numeric, errors='coerce')
    X = X.apply(lambda x: x.astype(int) if x.dtype == 'bool' else x)
    return sm.add_constant(X)

results = []
plt.figure(figsize=(10, 8))

# Going through the models and computing some performance metrics
for i, features in enumerate(model_features):
    X_subset = preprocess_df(df, features)
    y = pd.to_numeric(df['earnings_per_hour'], errors='coerce')
    
    # Fitting OLS model
    model = sm.OLS(y, X_subset).fit()
    y_pred = model.predict(X_subset)
    rmse = np.sqrt(mean_squared_error(y, y_pred))
    bic = model.bic
        
    # Cross-validation of RMSE
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    lin_reg = LinearRegression()
    cv_rmse = np.sqrt(-cross_val_score(lin_reg, X_subset, y, cv=kf, scoring='neg_mean_squared_error').mean())
   
    results.append([f'Model {i+1}', rmse, cv_rmse, model.bic])
    
    # Plotting the residuals
    plt.subplot(2, 2, i+1)
    sns.scatterplot(x=y_pred, y=(y - y_pred))
    plt.axhline(y=0, color='r', linestyle='--')
    plt.title(f'Predicted values and residuals for Model {i+1}')
    plt.xlabel('Predicted values')
    plt.ylabel('Residuals')

plt.tight_layout()
plt.show()

# %%
results_df = pd.DataFrame(results, columns=['Model', 'RMSE', 'CV RMSE', 'BIC'])
print(results_df)
# Out:
#      Model       RMSE    CV RMSE           BIC
# 0  Model 1  12.232933  12.238575  25351.347845
# 1  Model 2  11.836293  11.846405  25154.643748
# 2  Model 3  11.415899  11.427523  24929.179886
# 3  Model 4  11.286256  11.313732  24895.820947

# %%
# Creating Dataframe from results
metrics_df = pd.DataFrame(results, columns=['Model', 'RMSE', 'CV RMSE', 'BIC'])

# Defining metric names and labels
metrics = ['RMSE', 'CV RMSE', 'BIC']
titles = ['RMSE for Different Models', 'Cross-validated RMSE for Different Models', 'BIC for Different Models']

# Plotting the metrics
plt.figure(figsize=(12, 5))

for i, (metric, title) in enumerate(zip(metrics, titles), 1):
    plt.subplot(1, 3, i)
    sns.lineplot(x=metrics_df['Model'], y=metrics_df[metric], marker='o')
    plt.title(title)
    plt.xlabel('Model')
    plt.ylabel(metric)

plt.tight_layout()
plt.show()
